# %%
steps are:
    1- Frequent pattern set
    2- ordered item set
    3- ordered-item set and conditional frequent pattern tree is build
    4- frequent pattern rules

# %% [markdown]
# # 1- Frequent pattern set

# %%
yani konce product kitni dfa buy hua h

# %%
from IPython.display import Image
Image(filename='dataset.png', width=300, height=300)

# %%
in above dataset : frequent pattern set will be:
    A=1
    N=2
    C=2
    D=1
    E=4
    I=1
    K=5
    M=3
    O=3
    U=1
    Y=3
and we set minimum support as: 3
so frequent patterns set is:   K=5,E=4,M=3,O=3,Y=3

# %% [markdown]
# # 2- ordered item set

# %%
yani ab jo frequent pattern set nikalan hm n, us ki base pr items ko arrange krna h, like below

# %%
from IPython.display import Image
Image(filename='ordered item set.png', width=300, height=300)

# %%
yani KEMOY m K ko phly is liye rkha q k y 5 baar aya h then E ko q k 4 bar aya and so on

# %% [markdown]
# # 3- ordered-item set and conditional frequent pattern tree is build

# %%
ordered item set ki base pr hm fp growth tree bnayn gy like below:

# %%
from IPython.display import Image
Image(filename='fp growth tree.jpeg', width=300, height=300)

# %% [markdown]
# # 3,4- frequent pattern rules

# %%
from IPython.display import Image
Image(filename='moving from 3 to 4th step.png', width=300, height=300)
# y esy bna k tree jo final hua us m dekho k 'Y' s kon kon c branches nikal rhi, then 'O' s dekho then 'M' s then 'E' s
# yani end tak check kro yani tree k start tak

# %%
ab uper valy ko dekh kr hm n rules bnany hn, like below:
---> 'y' valy m common sirf 'k' h, yani 'k' k baad 'y' ay ga.
---> 'o' m 'EK' common h,yani esy ay ga: KEO: to combination bny ga: KE, KO and KEO
----> 'M' m 'K' common h just to combination will be just of 'KM'
----> 'E' m 'K' hi h to combination bhi just KE ka ho ga
