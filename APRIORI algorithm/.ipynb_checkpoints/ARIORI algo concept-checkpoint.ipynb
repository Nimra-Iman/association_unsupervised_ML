# %%
from IPython.display import Image
Image(filename='dataset.png', width=300, height=200)

# %%
1=========>>> first of all, set criterian of support and confidence, lets suppose i have put support=50% and criterion= 50%
means vo products jin ki support and confidence 50% s km h to hmy un products ko apni store m nhi daalna

--> e.g: consider above dataset:

# %%
in above dataset, the products having support greater than 50% are: K,E,M,O,Y  and A,C,D,I,N having support less than 50%

so of course, we wil only use K,E,M,O,Y in our store

# %%
2=========>>> now, we will pair them:
        KE (4 times)
        KM (3 TIMES) 
        KO (3 times)
        KY (3 times)
        EM (2 times)  ---> yani in dono ki support bhi 50% s km h , y bhi nikal den gy
        EO (3 times)
        EY (2 times)  ---> will exclude too
        MO (1 time)   ---> will exclude too
        MY (2 times)  ---> will exclude too
        OY (2 times)  ---> will exclude too

---> esy 3 3 ka bhi ho ga

# %%
so most bought products are:
K,E,M,O,Y,KE,KM,KO,KY,EO

# %%
3==========>>> now we will confidence:
       for(e=>k) is 100%
       for(k=>e) is 80%

--> to in 2 products ki arrangement bhi isi lehaz s ho gi
